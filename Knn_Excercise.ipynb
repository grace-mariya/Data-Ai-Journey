# %% [markdown]
# <a href="https://colab.research.google.com/github/grace-mariya/Data-Ai-Journey/blob/main/Knn_Excercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Data 1

# %%
df =  pd.read_csv('/content/drive/MyDrive/livingcost_india_all_inr (4).csv')
df
# Out:
#               City  cost_one_person_usd  rent_one_person_usd  \
# 0            Adoni                  346                132.0
# 1        Anantapur                  345                136.0
# 2          Chirala                  295                102.0
# 3         Chittoor                  400                 81.5
# 4            Eluru                  298                 89.2
# ..             ...                  ...                  ...
# 216       Siliguri                  297                 91.2
# 217   South Dumdum                  301                118.0
# 218       Uluberia                  324                119.0
# 219      Uttarpara                  312                116.0
# 220       Alleppey                  342                112.5
#
#      monthly_salary_after_tax_usd  income_after_rent_usd  months_covered  \
# 0                             329                  197.0             0.9
# 1                             571                  435.0             1.7
# ...

# %%
df.head()
# Out:
#          City  cost_one_person_usd  rent_one_person_usd  \
# 0       Adoni                  346                132.0
# 1   Anantapur                  345                136.0
# 2     Chirala                  295                102.0
# 3    Chittoor                  400                 81.5
# 4       Eluru                  298                 89.2
#
#    monthly_salary_after_tax_usd  income_after_rent_usd  months_covered  \
# 0                           329                  197.0             0.9
# 1                           571                  435.0             1.7
# 2                           555                  453.0             1.8
# 3                           404                  322.5             1.4
# 4                           384                  294.8             1.3
#
#    cost_one_person_inr  rent_one_person_inr  monthly_salary_after_tax_inr  \
# 0             30400.87             11598.02                      28907.19
# ...

# %%
df.tail()
# Out:
#               City  cost_one_person_usd  rent_one_person_usd  \
# 216       Siliguri                  297                 91.2
# 217   South Dumdum                  301                118.0
# 218       Uluberia                  324                119.0
# 219      Uttarpara                  312                116.0
# 220       Alleppey                  342                112.5
#
#      monthly_salary_after_tax_usd  income_after_rent_usd  months_covered  \
# 216                           279                  187.8             0.9
# 217                           370                  252.0             1.1
# 218                           376                  257.0             1.2
# 219                           291                  175.0             0.9
# 220                           301                  188.5             0.9
#
#      cost_one_person_inr  rent_one_person_inr  monthly_salary_after_tax_inr  \
# 216           26095.5500            8013.1800                    24514.0000
# ...

# %%
df.shape
# Out:
# (221, 12)

# %%
df.describe()
# Out:
#        cost_one_person_usd  rent_one_person_usd  monthly_salary_after_tax_usd  \
# count           221.000000           221.000000                    221.000000
# mean            357.932127           119.447059                    357.796380
# std              91.054379            47.159346                    104.077197
# min             251.000000            59.700000                    179.000000
# 25%             301.000000            92.800000                    280.000000
# 50%             329.000000           112.000000                    360.000000
# 75%             382.000000           129.000000                    406.000000
# max             705.000000           458.000000                    712.000000
#
#        income_after_rent_usd  months_covered  cost_one_person_inr  \
# count             221.000000      221.000000           221.000000
# mean              238.349321        1.095475         31449.276197
# std               114.603182        0.360653          8000.383058
# ...

# %%
df.dtypes
# Out:
# City                             object
# cost_one_person_usd               int64
# rent_one_person_usd             float64
# monthly_salary_after_tax_usd      int64
# income_after_rent_usd           float64
# months_covered                  float64
# cost_one_person_inr             float64
# rent_one_person_inr             float64
# monthly_salary_after_tax_inr    float64
# income_after_rent_inr           float64
# usd_to_inr_rate_used            float64
# source_url                       object
# dtype: object

# %%
df.isna().sum()
# Out:
# City                            0
# cost_one_person_usd             0
# rent_one_person_usd             0
# monthly_salary_after_tax_usd    0
# income_after_rent_usd           0
# months_covered                  0
# cost_one_person_inr             0
# rent_one_person_inr             0
# monthly_salary_after_tax_inr    0
# income_after_rent_inr           0
# usd_to_inr_rate_used            0
# source_url                      0
# dtype: int64

# %%
x=df.drop(columns = ['City', 'source_url'])
y=df['City']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = knn.predict(x_test)
y_pred
# Out:
# array([' Bardhaman', ' Adoni', ' Bardhaman', ' Aligarh', ' Ernakulam',
#        ' Akola', ' Bangalore', ' Aizawl', ' Cuttack', ' Aligarh',
#        ' Cuddalore', ' Aligarh', ' Cuttack', ' Agra', ' Asansol',
#        ' Durgapur', ' Durgapur', ' Adoni', ' Asansol', ' Adoni',
#        ' Baranagar', ' Agra', ' Aurangabad', ' Alleppey', ' Ernakulam',
#        ' Bhubaneswar', ' Ernakulam', ' Alleppey', ' Hyderabad, Telangana',
#        ' Bhatpara', ' Allahabad', ' Baranagar', ' Aurangabad', ' Adoni',
#        ' Bardhaman', ' Cuttack', ' Alleppey', ' Erode', ' Adoni',
#        ' Durgapur', ' Asansol', ' Alwar', ' Allahabad', ' Bally',
#        ' Aurangabad', ' Ernakulam', ' Allahabad', ' Cuttack',
#        ' Allahabad', ' Allahabad', ' Bhavnagar', ' Alleppey', ' Bally',
#        ' Bally', ' Dispur', ' Cuttack', ' Agra', ' Akola', ' Allahabad',
#        ' Alwar', ' Asansol', ' Bangalore', ' Baranagar', ' Akola',
#        ' Bardhaman', ' Alleppey', ' Allahabad'], dtype=object)

# %%
print(knn.predict(scaler.transform([['297',	'91.2',	'279',	'187.8',	'0.9',	'26095.5500',	'8013.1800',	'24514.0000',	'16500.8200',	'87.8638']])))
# Out:
# [' Durgapur']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Data 2:

# %%
df1 = pd.read_csv('/content/drive/MyDrive/merged_cities_data (2).csv')
df1
# Out:
#     SL NO                city  gdp_nominal_inr_billion  ua_population_lakhs  \
# 0       1              Mumbai                13417.150               234.87
# 1       2           Bangalore                 9285.520               131.93
# 2       3               Delhi                15375.370               320.66
# 3       4             Chennai                 7560.560               117.99
# 4       5           Ahmedabad                 5001.760                84.50
# 5       6                Pune                 4181.040                69.87
# 6       7               Surat                 3497.270                77.84
# 7       8          Coimbatore                 2684.220                47.34
# 8       9            Vadodara                 1708.060                22.77
# 9      10              Indore                  827.660                32.09
# 10     11             Kolkata                 6212.510               164.69
# ...

# %%
df1.describe()
# Out:
#            SL NO  gdp_nominal_inr_billion  ua_population_lakhs  eol_score  \
# count  30.000000                30.000000            30.000000   9.000000
# mean   15.500000              3195.248467            63.945333  61.994444
# std     8.803408              3822.752912            70.009573   3.311530
# min     1.000000               826.000000            17.360000  58.230000
# 25%     8.250000               906.240000            23.947500  59.240000
# 50%    15.500000              1290.860000            33.260000  61.730000
# 75%    22.750000              4010.097500            75.847500  64.870000
# max    30.000000             15375.370000           320.660000  66.700000
#
#         gdp_norm   pop_norm  eol_norm_filled  composite_score  \
# count  30.000000  30.000000        30.000000        30.000000
# mean    0.207816   0.199418         0.278836         0.228690
# std     0.248628   0.218330         0.433994         0.243578
# ...

# %%
df1.head()
# Out:
#    SL NO       city  gdp_nominal_inr_billion  ua_population_lakhs  eol_score  \
# 0      1     Mumbai                 13417.15               234.87      58.23
# 1      2  Bangalore                  9285.52               131.93      66.70
# 2      3      Delhi                 15375.37               320.66        NaN
# 3      4    Chennai                  7560.56               117.99      62.61
# 4      5  Ahmedabad                  5001.76                84.50      64.87
#
#    gdp_norm  pop_norm  eol_norm_filled  composite_score  \
# 0  0.872639  0.732458         0.873013         0.826037
# 1  0.603922  0.411433         1.000000         0.671785
# 2  1.000000  1.000000         0.000000         0.666667
# 3  0.491732  0.367960         0.938681         0.599457
# 4  0.325310  0.263519         0.972564         0.520464
#
#                                        justification  ... rent_one_person_usd  \
# 0  Highest contributor: EoL (GDP_norm=0.873, pop_...  ...               401.0
# ...

# %%
df1.tail()
# Out:
#     SL NO         city  gdp_nominal_inr_billion  ua_population_lakhs  \
# 25     26       Kollam                   975.56                20.26
# 26     27       Nashik                   864.35                21.80
# 27     28   Chandigarh                   966.20                17.36
# 28     29  Bhubaneswar                   843.11                19.89
# 29     30     Alleppey                   826.00                19.16
#
#     eol_score  gdp_norm  pop_norm  eol_norm_filled  composite_score  \
# 25        NaN  0.063450  0.063182              0.0         0.042211
# 26        NaN  0.056217  0.067985              0.0         0.041400
# 27        NaN  0.062841  0.054138              0.0         0.038993
# 28        NaN  0.054835  0.062028              0.0         0.038954
# 29        NaN  0.053722  0.059752              0.0         0.037825
#
#                                         justification  ...  \
# 25  Highest contributor: GDP (GDP_norm=0.063, pop_...  ...
# ...

# %%
df1.shape
# Out:
# (30, 23)

# %%
df1.dtypes
# Out:
# SL NO                             int64
# city                             object
# gdp_nominal_inr_billion         float64
# ua_population_lakhs             float64
# eol_score                       float64
# gdp_norm                        float64
# pop_norm                        float64
# eol_norm_filled                 float64
# composite_score                 float64
# justification                    object
# citations                        object
# matched_source_url_in_master     object
# cost_one_person_usd               int64
# rent_one_person_usd             float64
# monthly_salary_after_tax_usd      int64
# income_after_rent_usd           float64
# months_covered                  float64
# cost_one_person_inr             float64
# rent_one_person_inr             float64
# monthly_salary_after_tax_inr    float64
# income_after_rent_inr           float64
# usd_to_inr_rate_used            float64
# source_url                       object
# dtype: object

# %%
df1.isna().sum()
# Out:
# SL NO                            0
# city                             0
# gdp_nominal_inr_billion          0
# ua_population_lakhs              0
# eol_score                       21
# gdp_norm                         0
# pop_norm                         0
# eol_norm_filled                  0
# composite_score                  0
# justification                    0
# citations                        0
# matched_source_url_in_master     4
# cost_one_person_usd              0
# rent_one_person_usd              0
# monthly_salary_after_tax_usd     0
# income_after_rent_usd            0
# months_covered                   0
# cost_one_person_inr              0
# rent_one_person_inr              0
# monthly_salary_after_tax_inr     0
# income_after_rent_inr            0
# usd_to_inr_rate_used             0
# source_url                       0
# dtype: int64

# %%
df1.drop(columns=['eol_score','justification','citations','matched_source_url_in_master','source_url'],inplace=True)

# %%
x1 = df1.drop(columns=['city'])
y1 = df1['city']

# %%
df1
# Out:
#     SL NO                city  gdp_nominal_inr_billion  ua_population_lakhs  \
# 0       1              Mumbai                13417.150               234.87
# 1       2           Bangalore                 9285.520               131.93
# 2       3               Delhi                15375.370               320.66
# 3       4             Chennai                 7560.560               117.99
# 4       5           Ahmedabad                 5001.760                84.50
# 5       6                Pune                 4181.040                69.87
# 6       7               Surat                 3497.270                77.84
# 7       8          Coimbatore                 2684.220                47.34
# 8       9            Vadodara                 1708.060                22.77
# 9      10              Indore                  827.660                32.09
# 10     11             Kolkata                 6212.510               164.69
# ...

# %%
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.3)

# %%
scaler1 = StandardScaler()
scaler1.fit(x1_train)
x1_train = scaler1.transform(x1_train)
x1_test  = scaler1.transform(x1_test)

# %%
KNN = KNeighborsClassifier(n_neighbors=5)
KNN.fit(x1_train,y1_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = KNN.predict(x1_test)
y_pred
# Out:
# array(['Ahmedabad', 'Alleppey', 'Ahmedabad', 'Alleppey', 'Alleppey',
#        'Alleppey', 'Ahmedabad', 'Ahmedabad', 'Alleppey'], dtype=object)

# %%
print(KNN.predict(scaler1.transform([['1','13417.150',	'234.87',	'0.872639',	'0.732458',	'0.873013',	'0.826037',	'705',	'401.0',	'222',	'-179.0',	'0.3',	'61943.9800',	'35233.3800',	'19505.7600',	'-15727.6200',	'87.8638']])))
# Out:
# ['Ahmedabad']
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
